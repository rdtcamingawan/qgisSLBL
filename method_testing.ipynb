# %%
from osgeo import gdal
import numpy as np

file_path = r'D:/AMH Philippines, Inc/Rockwell and Roll - Debris Flows/Test Case/test_raster_0.5m_LiDAR.tif'

# %%
ds = gdal.Open(file_path)
band1= ds.GetRasterBand(1)
rows = ds.RasterYSize
cols = ds.RasterXSize

data = band1.ReadAsArray(0,0,cols, rows)
data.shape
# Out:
# (12000, 16000)
